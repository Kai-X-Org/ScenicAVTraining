# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
adv = np.load("train_info_adv.npy")
adv_time = adv[:,0]
adv_rew = adv[:, 1]
plt.figure()
plt.plot(adv_time, adv_rew)
plt.xlabel("timestep")
plt.ylabel("reward")
plt.show()

# %%
uni = np.load("train_info_regular.npy")
uni_time = uni[:,0]
uni_rew = uni[:, 1]
plt.figure()
plt.plot(uni_time, uni_rew)
plt.xlabel("timestep")
plt.ylabel("reward")
plt.show()
