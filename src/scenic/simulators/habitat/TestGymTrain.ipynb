# %%
import gymnasium as gym
# from scenic.zoo import ScenicZooEnv
from scenic.gym import ScenicGymEnv
from ray.rllib.algorithms.ppo import PPOConfig
# from ray.rllib.env.wrappers.pettingzoo_env import ParallelPettingZooEnv
from ray.tune.registry import register_env
from pprint import pprint
import os
import numpy as np
import scenic
# from scenic.simulators.metadrive import MetaDriveSimulator
from scenic.simulators.habitat import HabitatSimulator
from ray.rllib.core.rl_module.default_model_config import DefaultModelConfig
import datetime
# Out:
# /home/kxu/ScenicGymClean/src/scenic/core/errors.py:271: UserWarning: unable to install sys.excepthook to format Scenic backtraces
#   warnings.warn("unable to install sys.excepthook to format Scenic backtraces")
# /home/kxu/miniforge3/envs/sgym-hab/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))

# %%
def scenic_env():

    root_user = os.path.expanduser("~")
    obs_space = gym.spaces.Box(0, 255, (256, 256, 3), np.uint8)
    action_space = gym.spaces.Box(-5.0, 5.0, (2,), np.float32) # habitat uses +/- 20.0, but let's just use 5

    scenic_file = "train_scenes/train.scenic"
    # print("Making Scenario")

    scenario = scenic.scenarioFromFile(scenic_file,
                                   model="scenic.simulators.habitat.model",
                               mode2D=False)

    # print("Made Scenario")
    env = ScenicGymEnv(scenario, 
                       HabitatSimulator(),
                       render_mode=None, 
                       max_steps=150, 
                       observation_space=obs_space, 
                       action_space=action_space
                       )
    return env

# %%
env = scenic_env()
action = [1, 0]
env.reset()
#for _ in range(100)
# Out:
# 2025-06-19 23:27:17,671 Initializing dataset RearrangeDataset-v0
# 2025-06-19 23:27:17,675 initializing sim RearrangeSim-v0
# Setting up agent:  SpotRobot
# obj agent id: 0
# Object name: agent_0
# Setting up agent:  FetchRobot
# obj agent id: 1
# Object name: agent_1
# /home/kxu/habitat-lab/data/hab3_bench_assets/hab3-hssd/scenes/103997919_171031233.scene_instance.json
# /home/kxu/habitat-lab/data/hab3_bench_assets/hab3-hssd/hab3-hssd.scene_dataset_config.json
# finished init configs!!!
# [23:27:17:874601]:[Error]:[Scene] SemanticScene.cpp(139)::loadSemanticSceneDescriptor : SSD Load Failure! File with SemanticAttributes-provided name `../hssd-hab_semantic_lexicon.json` exists but failed to load.
# 2025-06-19 23:27:18,133 Initializing task RearrangeEmptyTask-v0
# Renderer: NVIDIA TITAN RTX/PCIe/SSE2 by NVIDIA Corporation
# OpenGL version: 4.6.0 NVIDIA 525.60.11
# Using optional features:
#     GL_ARB_vertex_array_object
#     GL_ARB_separate_shader_objects
#     GL_ARB_robustness
#     GL_ARB_texture_storage
#     GL_ARB_texture_view
#     GL_ARB_framebuffer_no_attachments
#     GL_ARB_invalidate_subdata
#     GL_ARB_texture_storage_multisample
#     GL_ARB_multi_bind
#     GL_ARB_direct_state_access
#     GL_ARB_get_texture_sub_image
#     GL_ARB_texture_filter_anisotropic
#     GL_KHR_debug
#     GL_KHR_parallel_shader_compile
#     GL_NV_depth_buffer_float
# Using driver workarounds:
#     no-forward-compatible-core-context
#     nv-egl-incorrect-gl11-function-pointers
#     no-layout-qualifiers-on-old-glsl
#     nv-zero-context-profile-mask
#     nv-implementation-color-read-format-dsa-broken
#     nv-cubemap-inconsistent-compressed-image-size
#     nv-cubemap-broken-full-compressed-image-query
#     nv-compressed-block-size-in-bits
# initializing!
# agent_0_base_vel Dict(agent_0_base_vel:Box(-20.0, 20.0, (2,), float32))
# agent_0_oracle_coord_action Dict(agent_0_mode:Discrete(3), agent_0_oracle_nav_coord_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32), agent_0_oracle_nav_lookat_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32))
# agent_0_oracle_magic_grasp_action Box(-1.0, 1.0, (1,), float32)
# agent_1_base_vel Dict(agent_1_base_vel:Box(-20.0, 20.0, (2,), float32))
# agent_1_oracle_coord_action Dict(agent_1_mode:Discrete(3), agent_1_oracle_nav_coord_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32), agent_1_oracle_nav_lookat_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32))
# agent_1_oracle_magic_grasp_action Box(-1.0, 1.0, (1,), float32)
# agent_0_base_vel Dict(agent_0_base_vel:Box(-20.0, 20.0, (2,), float32))
# agent_0_oracle_coord_action Dict(agent_0_mode:Discrete(3), agent_0_oracle_nav_coord_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32), agent_0_oracle_nav_lookat_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32))
# agent_0_oracle_magic_grasp_action Box(-1.0, 1.0, (1,), float32)
# agent_1_base_vel Dict(agent_1_base_vel:Box(-20.0, 20.0, (2,), float32))
# agent_1_oracle_coord_action Dict(agent_1_mode:Discrete(3), agent_1_oracle_nav_coord_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32), agent_1_oracle_nav_lookat_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32))
# agent_1_oracle_magic_grasp_action Box(-1.0, 1.0, (1,), float32)
# (None, None)

# %%
for i in range(3):
    print("New episode")
    for j in range(100):
        print(f"step number: {j}")
        o, r, d, t, info = env.step(action)
    env.reset()
# Out:
# New episode
# step number: 0
# step number: 1
# step number: 2
# step number: 3
# step number: 4
# step number: 5
# step number: 6
# step number: 7
# step number: 8
# step number: 9
# step number: 10
# step number: 11
# step number: 12
# step number: 13
# step number: 14
# step number: 15
# step number: 16
# step number: 17
# step number: 18
# step number: 19
# step number: 20
# step number: 21
# step number: 22
# step number: 23
# step number: 24
# step number: 25
# step number: 26
# step number: 27
# step number: 28
# step number: 29
# step number: 30
# step number: 31
# step number: 32
# step number: 33
# step number: 34
# step number: 35
# step number: 36
# step number: 37
# step number: 38
# step number: 39
# step number: 40
# step number: 41
# step number: 42
# step number: 43
# step number: 44
# step number: 45
# step number: 46
# step number: 47
# step number: 48
# step number: 49
# step number: 50
# FINISH SCENE, DESTROYING...
# step number: 51
# FINISH SCENE, DESTROYING...
# initializing!
# agent_0_base_vel Dict(agent_0_base_vel:Box(-20.0, 20.0, (2,), float32))
# agent_0_oracle_coord_action Dict(agent_0_mode:Discrete(3), agent_0_oracle_nav_coord_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32), agent_0_oracle_nav_lookat_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32))
# agent_0_oracle_magic_grasp_action Box(-1.0, 1.0, (1,), float32)
# agent_1_base_vel Dict(agent_1_base_vel:Box(-20.0, 20.0, (2,), float32))
# agent_1_oracle_coord_action Dict(agent_1_mode:Discrete(3), agent_1_oracle_nav_coord_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32), agent_1_oracle_nav_lookat_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32))
# agent_1_oracle_magic_grasp_action Box(-1.0, 1.0, (1,), float32)
# agent_0_base_vel Dict(agent_0_base_vel:Box(-20.0, 20.0, (2,), float32))
# agent_0_oracle_coord_action Dict(agent_0_mode:Discrete(3), agent_0_oracle_nav_coord_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32), agent_0_oracle_nav_lookat_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32))
# agent_0_oracle_magic_grasp_action Box(-1.0, 1.0, (1,), float32)
# agent_1_base_vel Dict(agent_1_base_vel:Box(-20.0, 20.0, (2,), float32))
# agent_1_oracle_coord_action Dict(agent_1_mode:Discrete(3), agent_1_oracle_nav_coord_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32), agent_1_oracle_nav_lookat_action:Box(-3.4028235e+38, 3.4028235e+38, (3,), float32))
# agent_1_oracle_magic_grasp_action Box(-1.0, 1.0, (1,), float32)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       3 for j in range(100):
#       4     print(f"step number: {j}")
# ----> 5     o, r, d, t, info = env.step(action)
#       6 env.reset()
#
# File ~/ScenicGymClean/src/scenic/gym/envs/scenic_gym.py:96, in ScenicGymEnv.step(self, action)
#      93 def step(self, action):
#      94     assert not (self.loop is None), "self.loop is None, have you called reset()?"
# ---> 96     observation, reward, terminated, truncated, info = self.loop.send(action)
#      97     return observation, reward, terminated, truncated, info
#
# ValueError: not enough values to unpack (expected 5, got 2)
